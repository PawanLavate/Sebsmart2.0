# %%
# !pip install flask numpy tensorflow pillow

# %%
from flask import Flask, request, jsonify
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import io
from PIL import Image

app = Flask(__name__)
model = load_model("mobilenetV2_apple_disease_classifier.keras")

CLASS_NAMES = ['alternaria_leaf_spot', 'black_rot', 'cedar_apple', 'healthy', 'mosaic', 'powdery_mildew', 'scab']

def preprocess(img):
    img = img.resize((224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0
    return img_array

@app.route("/pests", methods=["POST"])
def predict():
    file = request.files['file']
    img = Image.open(io.BytesIO(file.read()))
    img_array = preprocess(img)
    
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions[0])
    confidence = float(np.max(predictions[0]))

    return jsonify({
        "class_name": CLASS_NAMES[predicted_class],
        "confidence": confidence
    })

if __name__ == "__main__":
    app.run(port=5000, debug=False, use_reloader=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       6 from PIL import Image
#       8 app = Flask(__name__)
# ----> 9 model = load_model("mobilenetV2_apple_disease_classifier.keras")
#      11 CLASS_NAMES = ['alternaria_leaf_spot', 'black_rot', 'cedar_apple', 'healthy', 'mosaic', 'powdery_mildew', 'scab']
#      13 def preprocess(img):
#
# File c:\Users\harsh\TY\MIni_project_imp\venev\Lib\site-packages\keras\src\saving\saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)    220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=mobilenetV2_apple_disease_classifier.keras. Please ensure the file is an accessible `.keras` zip file.
